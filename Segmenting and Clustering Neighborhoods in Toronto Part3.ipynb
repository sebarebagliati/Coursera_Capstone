# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering Neighborhoods in Toronto</font></h1>

# %% [markdown]
# Firstly, I download all the dependencies needed:

# %%
#first I install geopy & folium
# !conda install -c conda-forge geopy --yes 
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.18.1               |             py_0          51 KB  conda-forge
#     openssl-1.0.2p             |       h470a237_2         3.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0         conda-forge
#     geopy:         1.18.1-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     openssl:       1.0.2p-h470a237_1 conda-forge --> 1.0.2p-h470a237_2 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.18.1         | 51 KB     | ##################################### | 100%
# openssl-1.0.2p       | 3.1 MB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-2.3.0               |        py36_1001         533 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         631 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.3.0-py36_1001 conda-forge
#     branca:  0.3.1-py_0      conda-forge
#     folium:  0.5.0-py_0      conda-forge
#     vincent: 0.4.4-py_1      conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-2.3.0         | 533 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#then, I import the libraries needed
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

from geopy.geocoders import Nominatim 

import requests 
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

import folium

import lxml.html as lh

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# Now I get the table from the web page:

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

page = requests.get(url)

doc = lh.fromstring(page.content)

tr_elements = doc.xpath('//tr')

col=[]
i=0
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print (i,name)
    col.append((name,[]))
# Out:
# 1 Postcode
# 2 Borough
# 3 Neighbourhood

# %%
for j in range(1,len(tr_elements)):
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from the table 
    if len(T)!=3:
        break
    
    i=0
    for t in T.iterchildren():
        data=t.text_content() 
        if i>0:
            try:
                data=int(data)
            except:
                pass
        col[i][1].append(data)
        i+=1

# %% [markdown]
# Now I make it a Pandas DataFrame:

# %%
Dict={title:column for (title,column) in col}
df1=pd.DataFrame(Dict)
df1.head()
# Out:
#   Postcode           Borough     Neighbourhood\n
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %% [markdown]
# Now I remove rows where Borough is not assigned and reset the index, remove the \n from the Neighbourhood column, and fix the Postcode column name to fit the example:

# %%
df2 = df1[~df1['Borough'].isin(['Not assigned'])]
df3= df2.reset_index(drop=True)
df4=df3.rename(index=str, columns={"Postcode": "Postal Code"})
df=df4.rename(index=str, columns={"Neighbourhood\n": "Neighborhood"})
df['Neighborhood']= df['Neighborhood'].str.lstrip('+-').str.rstrip('\n')
df.head(7)
# Out:
#   Postal Code           Borough      Neighborhood
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto      Harbourfront
# 3         M5A  Downtown Toronto       Regent Park
# 4         M6A        North York  Lawrence Heights
# 5         M6A        North York    Lawrence Manor
# 6         M7A      Queen's Park      Not assigned

# %% [markdown]
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough

# %%
for i in df.index:
    if df['Neighborhood'][i] == 'Not assigned':
        df.at[i, 'Neighborhood'] = df['Borough'][i]
    else:
        df.at[i, 'Neighborhood'] = df['Neighborhood'][i]
df.head(7)
# Out:
#   Postal Code           Borough      Neighborhood
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto      Harbourfront
# 3         M5A  Downtown Toronto       Regent Park
# 4         M6A        North York  Lawrence Heights
# 5         M6A        North York    Lawrence Manor
# 6         M7A      Queen's Park      Queen's Park

# %% [markdown]
# Now I combine rows that have the same PostalCode but different neighborhoods

# %%
df = df.groupby(['Postal Code','Borough'], sort = False, as_index=False).agg(lambda x: ', '.join(x))
df.head()
# Out:
#   Postal Code           Borough                      Neighborhood
# 0         M3A        North York                         Parkwoods
# 1         M4A        North York                  Victoria Village
# 2         M5A  Downtown Toronto         Harbourfront, Regent Park
# 3         M6A        North York  Lawrence Heights, Lawrence Manor
# 4         M7A      Queen's Park                      Queen's Park

# %%
print ('The dataframe has', df.shape[0], 'rows')
# Out:
# The dataframe has 103 rows

# %% [markdown]
# Now we add Geospatial data:

# %%
lg = pd.read_csv('https://cocl.us/Geospatial_data')
dflg = pd.merge(df, lg, left_on = 'Postal Code', right_on = 'Postal Code')
dflg.head()
# Out:
#   Postal Code           Borough                      Neighborhood   Latitude  \
# 0         M3A        North York                         Parkwoods  43.753259
# 1         M4A        North York                  Victoria Village  43.725882
# 2         M5A  Downtown Toronto         Harbourfront, Regent Park  43.654260
# 3         M6A        North York  Lawrence Heights, Lawrence Manor  43.718518
# 4         M7A      Queen's Park                      Queen's Park  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# I will work with only boroughs that contain the word Toronto and then explore and map the data.

# %% [markdown]
# First we get the coordinates of Toronto:

# %%
address = 'Toronto, CA'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# Now I get a dataframe that only contains boroughs in Toronto:

# %%
dft2 = dflg[dflg['Borough'].str.contains("Toronto")]
dft = dft2.reset_index(drop = True)
dft.head()
# Out:
#   Postal Code           Borough               Neighborhood   Latitude  \
# 0         M5A  Downtown Toronto  Harbourfront, Regent Park  43.654260
# 1         M5B  Downtown Toronto   Ryerson, Garden District  43.657162
# 2         M5C  Downtown Toronto             St. James Town  43.651494
# 3         M4E      East Toronto                The Beaches  43.676357
# 4         M5E  Downtown Toronto                Berczy Park  43.644771
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.293031
# 4 -79.373306

# %% [markdown]
# Then I create a map:

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(dft['Latitude'], dft['Longitude'], dft['Borough'], dft['Neighborhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we explore nearby venues with Foursquare:

# %%
CLIENT_ID = 'Z15JZA0CDQLNUGIUFAIX4IPUZKZ024ZURVNQVWP5UHFHDXJ3' 
CLIENT_SECRET = 'VJXBHHIAJ3Z3RKNAWSAOP1GZDEHSBPHNN4SLF0P4JWXX4WGE' 
VERSION = '20180605' 

LIMIT = 100

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=dft['Neighborhood'],
                                   latitudes=dft['Latitude'],
                                   longitudes=dft['Longitude']
                                  )
toronto_venues.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Harbourfront, Regent Park               43.65426              -79.360636
# 1  Harbourfront, Regent Park               43.65426              -79.360636
# 2  Harbourfront, Regent Park               43.65426              -79.360636
# 3  Harbourfront, Regent Park               43.65426              -79.360636
# 4  Harbourfront, Regent Park               43.65426              -79.360636
#
#                                              Venue  Venue Latitude  \
# 0                                 Roselle Desserts       43.653447
# 1                                    Tandem Coffee       43.653559
# 2  Toronto Cooper Koo Family Cherry St YMCA Centre       43.653191
# 3                               Morning Glory Cafe       43.653947
# 4                              Body Blitz Spa East       43.654735
#
#    Venue Longitude        Venue Category
# 0       -79.362017                Bakery
# 1       -79.361809           Coffee Shop
# 2       -79.357947  Gym / Fitness Center
# 3       -79.361149        Breakfast Spot
# 4       -79.359874                   Spa

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2       Brockton, Exhibition Place, Parkdale Village           Coffee Shop
# 3  Business Reply Mail Processing Centre 969 Eastern           Yoga Studio
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...        Airport Lounge
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café            Steakhouse   American Restaurant
# 1            Restaurant          Cocktail Bar                  Café
# 2                  Café        Breakfast Spot                   Bar
# 3         Auto Workshop                  Park           Pizza Place
# 4       Airport Service      Airport Terminal                 Plane
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0       Thai Restaurant            Restaurant      Asian Restaurant
# 1        Farmers Market            Steakhouse                   Pub
# 2               Stadium         Burrito Place    Italian Restaurant
# 3         Moving Target      Recording Studio            Restaurant
# 4              Boutique       Harbor / Marina               Airport
#
#   8th Most Common Venue 9th Most Common Venue  10th Most Common Venue
# 0                Bakery                   Bar          Clothing Store
# 1    Seafood Restaurant                Bakery             Cheese Shop
# 2          Climbing Gym                Office  Furniture / Home Store
# 3         Burrito Place               Brewery              Skate Park
# 4    Airport Food Court          Airport Gate           Boat or Ferry

# %% [markdown]
# Now, I will run *k*-means to cluster the neighborhood into 5 clusters and show it on the map:

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 1, 2, 2, 2, 2, 2, 2], dtype=int32)

# %%
toronto_merged = neighborhoods_venues_sorted

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

toronto_full = pd.merge(dft, toronto_merged, left_on='Neighborhood', right_on='Neighborhood')

toronto_full.head()
# Out:
#   Postal Code           Borough               Neighborhood   Latitude  \
# 0         M5A  Downtown Toronto  Harbourfront, Regent Park  43.654260
# 1         M5B  Downtown Toronto   Ryerson, Garden District  43.657162
# 2         M5C  Downtown Toronto             St. James Town  43.651494
# 3         M4E      East Toronto                The Beaches  43.676357
# 4         M5E  Downtown Toronto                Berczy Park  43.644771
#
#    Longitude 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.360636           Coffee Shop                Bakery
# 1 -79.378937           Coffee Shop        Clothing Store
# 2 -79.375418           Coffee Shop            Restaurant
# 3 -79.293031           Coffee Shop  Gym / Fitness Center
# 4 -79.373306           Coffee Shop            Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                   Pub                  Park                       Café
# 1                  Café        Cosmetics Shop  Middle Eastern Restaurant
# 2                  Café                 Hotel             Clothing Store
# 3                   Pub         Women's Store             Discount Store
# 4          Cocktail Bar                  Café             Farmers Market
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0               Theater        Breakfast Spot            Restaurant
# 1                 Plaza       Thai Restaurant           Pizza Place
# 2    Italian Restaurant        Cosmetics Shop          Cocktail Bar
# 3  Fast Food Restaurant        Farmers Market    Falafel Restaurant
# 4            Steakhouse                   Pub    Seafood Restaurant
#
#   9th Most Common Venue 10th Most Common Venue  Cluster Labels
# 0    Mexican Restaurant                   Bank               2
# 1                 Diner               Tea Room               2
# 2             Gastropub         Breakfast Spot               2
# 3           Event Space   Ethiopian Restaurant               2
# 4                Bakery            Cheese Shop               2

# %%
#create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_full['Latitude'], toronto_full['Longitude'], toronto_full['Neighborhood'], toronto_full['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Finally, we examine each cluster to determine if there are any discriminating venue categories that distinguish them:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    1st Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 24            Playground        Farmers Market    Falafel Restaurant
# 27                  Park  Fast Food Restaurant        Farmers Market
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 24           Event Space  Ethiopian Restaurant                 Diner
# 27    Falafel Restaurant           Event Space  Ethiopian Restaurant
#
#    10th Most Common Venue  Cluster Labels
# 24      Electronics Store               0
# 27      Electronics Store               0

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    1st Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 3            Yoga Studio         Moving Target      Recording Studio
# 12                  Park          Dance Studio        Clothing Store
# 22              Bus Line         Women's Store   Filipino Restaurant
# 36                  Park            Board Shop          Liquor Store
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 3             Restaurant         Burrito Place               Brewery
# 12        Sandwich Place                 Hotel         Grocery Store
# 22  Fast Food Restaurant        Farmers Market    Falafel Restaurant
# 36     Fish & Chips Shop          Burger Joint        Sandwich Place
#
#    10th Most Common Venue  Cluster Labels
# 3              Skate Park               1
# 12                    Gym               1
# 22            Event Space               1
# 36          Burrito Place               1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    1st Most Common Venue      5th Most Common Venue 6th Most Common Venue  \
# 0            Coffee Shop            Thai Restaurant            Restaurant
# 1            Coffee Shop             Farmers Market            Steakhouse
# 2            Coffee Shop                    Stadium         Burrito Place
# 4         Airport Lounge                   Boutique       Harbor / Marina
# 5            Coffee Shop                     Market                   Pub
# 6            Coffee Shop                        Bar       Thai Restaurant
# 7                    Bar      Vietnamese Restaurant                Bakery
# 8                   Café                      Diner    Italian Restaurant
# 9    Japanese Restaurant                 Restaurant          Burger Joint
# 10           Coffee Shop        American Restaurant             Gastropub
# 11           Pizza Place         Seafood Restaurant                  Café
# 13                   Pub           Sushi Restaurant            Bagel Shop
# 14           Coffee Shop                 Restaurant         Deli / Bodega
# 15              Pharmacy                       Park                  Pool
# 16           Coffee Shop        American Restaurant             Gastropub
# 18                  Café                        Bar                Bakery
# 19           Coffee Shop                Pizza Place    Italian Restaurant
# 20           Coffee Shop                       Café               Theater
# 21    Mexican Restaurant                  Bookstore        Sandwich Place
# 23                   Bar                Coffee Shop                  Café
# 25   Sporting Goods Shop             Sandwich Place                 Diner
# 26        Breakfast Spot                       Bank            Restaurant
# 29           Coffee Shop                      Diner    Italian Restaurant
# 30           Coffee Shop  Middle Eastern Restaurant                 Plaza
# 31           Coffee Shop             Clothing Store    Italian Restaurant
# 32           Coffee Shop                   Beer Bar    Seafood Restaurant
# 33                  Café        American Restaurant           Yoga Studio
# 34           Coffee Shop             History Museum     Indian Restaurant
# 35           Coffee Shop             Discount Store  Fast Food Restaurant
# 37      Greek Restaurant         Italian Restaurant           Yoga Studio
#
#     7th Most Common Venue      8th Most Common Venue  \
# 0        Asian Restaurant                     Bakery
# 1                     Pub         Seafood Restaurant
# 2      Italian Restaurant               Climbing Gym
# 4                 Airport         Airport Food Court
# 5                  Bakery                       Café
# 6      Falafel Restaurant            Bubble Tea Shop
# 7     Dumpling Restaurant         Mexican Restaurant
# 8               Nightclub                 Restaurant
# 9                    Café                        Pub
# 10                    Gym              Deli / Bodega
# 11       Sushi Restaurant                Coffee Shop
# 13             Sports Bar                Supermarket
# 14     Italian Restaurant                        Gym
# 15            Music Venue                       Café
# 16                    Bar         Seafood Restaurant
# 18    Japanese Restaurant         Chinese Restaurant
# 19                Brewery                 Restaurant
# 20         Breakfast Spot                 Restaurant
# 21              Speakeasy  Cajun / Creole Restaurant
# 23  Vietnamese Restaurant                     Bakery
# 25    Rental Car Location     Furniture / Home Store
# 26              Bookstore                    Dog Run
# 29                    Gym                  Bookstore
# 30        Thai Restaurant                Pizza Place
# 31         Cosmetics Shop               Cocktail Bar
# 32                    Pub                      Hotel
# 33        Coworking Space         Seafood Restaurant
# 34               Pharmacy             Cosmetics Shop
# 35         Farmers Market         Falafel Restaurant
# 37         Cosmetics Shop                    Brewery
#
#         9th Most Common Venue  10th Most Common Venue  Cluster Labels
# 0                         Bar          Clothing Store               2
# 1                      Bakery             Cheese Shop               2
# 2                      Office  Furniture / Home Store               2
# 4                Airport Gate           Boat or Ferry               2
# 5                   Pet Store    Caribbean Restaurant               2
# 6          Chinese Restaurant       Indian Restaurant               2
# 7          Chinese Restaurant      Dim Sum Restaurant               2
# 8                 Coffee Shop       Convenience Store               2
# 9             Bubble Tea Shop             Men's Store               2
# 10                     Bakery              Steakhouse               2
# 11         Chinese Restaurant                   Diner               2
# 13        Fried Chicken Joint             Pizza Place               2
# 14                  Gastropub              Steakhouse               2
# 15  Middle Eastern Restaurant                 Brewery               2
# 16                     Bakery        Asian Restaurant               2
# 18             Sandwich Place              Beer Store               2
# 19             Scenic Lookout                  Bakery               2
# 20         Mexican Restaurant                    Bank               2
# 21                        Bar                  Bakery               2
# 23                Pizza Place            Cocktail Bar               2
# 25               Dessert Shop      Chinese Restaurant               2
# 26         Italian Restaurant                     Bar               2
# 29                       Food                     Bar               2
# 30                      Diner                Tea Room               2
# 31                  Gastropub          Breakfast Spot               2
# 32               Cocktail Bar                  Bakery               2
# 33             Sandwich Place             Cheese Shop               2
# 34                        Pub            Burger Joint               2
# 35                Event Space    Ethiopian Restaurant               2
# 37            Bubble Tea Shop              Restaurant               2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    1st Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 17              Bus Line         Women's Store   Filipino Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 17  Fast Food Restaurant        Farmers Market    Falafel Restaurant
#
#    10th Most Common Venue  Cluster Labels
# 17            Event Space               3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    1st Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 28                  Pool               Dog Run  Fast Food Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 28        Farmers Market    Falafel Restaurant           Event Space
#
#    10th Most Common Venue  Cluster Labels
# 28   Ethiopian Restaurant               4

# %% [markdown]
# We can conclude Label 2 marks places near to Coffee Shops, while 0 and 1 mark places near to open spaces.
